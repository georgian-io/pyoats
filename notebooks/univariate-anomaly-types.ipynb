# %%
import os

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view   
import optuna

# %%
from one.generator.univariate import UnivariateDataGenerator
from one.models import *
from one.utils import *
from one.scorer.pot import *

# %%
# %load_ext autoreload
# %autoreload 2

# %%
plt.rcParams["figure.figsize"] = 40,10
plt.rcParams["font.size"] = 15

# %% [markdown]
# # Generating Univariate Anomalies

# %%
generator = UnivariateDataGenerator(stream_length=5000)

# %%
generator.collective_seasonal_outliers(0.1, 1., 50)

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Train Set

# %%
plt.plot(generator.train)

# %% [markdown]
# ### Test Set

# %%
fig, axes = plt.subplots(2)

axes[0].plot(generator.test)
axes[1].plot(generator.label)

# %% [markdown]
# ## Save

# %%
SAVE_DIR = "./data/univar-synth/"

# %%
# Point Global
out_type = "point_global"
config_1 = [0.05, 1.1, 50] #ratio, factor, radius
config_2 = [0.05, 1.25, 50] #ratio, factor, radius
config_3 = [0.05, 1.5, 50] #ratio, factor, radius
config_4 = [0.05, 2, 50] #ratio, factor, radius
config_5 = [0.05, 3, 50] #ratio, factor, radius

for idx, config in enumerate([config_1, config_2, config_3, config_4, config_5]):
    generator = UnivariateDataGenerator(stream_length=5000)
    generator.point_global_outliers(*config)
    
    # save train
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-train.txt"
    np.savetxt(SAVE_DIR+file_name, generator.train)
    
    # save test
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-test.txt"
    np.savetxt(SAVE_DIR+file_name, generator.test)
    
    # save labels
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-labels.txt"
    np.savetxt(SAVE_DIR+file_name, generator.label)

# %%
# Point Contextual
out_type = "point_contextual"
config_1 = [0.05, 1.1, 50] #ratio, factor, radius
config_2 = [0.05, 1.25, 50] #ratio, factor, radius
config_3 = [0.05, 1.5, 50] #ratio, factor, radius
config_4 = [0.05, 2, 50] #ratio, factor, radius
config_5 = [0.05, 3, 50] #ratio, factor, radius

for idx, config in enumerate([config_1, config_2, config_3, config_4, config_5]):
    generator = UnivariateDataGenerator(stream_length=5000)
    generator.point_contextual_outliers(*config)
    
    # save train
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-train.txt"
    np.savetxt(SAVE_DIR+file_name, generator.train)
    
    # save test
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-test.txt"
    np.savetxt(SAVE_DIR+file_name, generator.test)
    
    # save labels
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-labels.txt"
    np.savetxt(SAVE_DIR+file_name, generator.label)

# %%
# Collective Global
out_type = "collective_global"
config_1 = [0.05, 50, 1.1] #ratio, radius, coef
config_2 = [0.05, 50, 1.25] #ratio, radius, coef
config_3 = [0.05, 50, 1.5] #ratio, radius, coef
config_4 = [0.05, 50, 2] #ratio, radius, coef
config_5 = [0.05, 50, 3] #ratio, radius, coef

for idx, config in enumerate([config_1, config_2, config_3, config_4, config_5]):
    *args, coef = config
    generator = UnivariateDataGenerator(stream_length=5000)
    generator.collective_global_outliers(*args, "square", coef=coef)
    
    # save train
    file_name = f"{out_type}/{idx}-{out_type}-factor{coef}-train.txt"
    np.savetxt(SAVE_DIR+file_name, generator.train)
    
    # save test
    file_name = f"{out_type}/{idx}-{out_type}-factor{coef}-test.txt"
    np.savetxt(SAVE_DIR+file_name, generator.test)
    
    # save labels
    file_name = f"{out_type}/{idx}-{out_type}-factor{coef}-labels.txt"
    np.savetxt(SAVE_DIR+file_name, generator.label)

# %%
# Collective Trend
out_type = "collective_trend"
config_1 = [0.05, 0.01, 50] #ratio, factor, radius
config_2 = [0.05, 0.02, 50] #ratio, factor, radius
config_3 = [0.05, 0.03, 50] #ratio, factor, radius
config_4 = [0.05, 0.04, 50] #ratio, factor, radius
config_5 = [0.05, 0.05, 50] #ratio, factor, radius

for idx, config in enumerate([config_1, config_2, config_3, config_4, config_5]):
    generator = UnivariateDataGenerator(stream_length=5000)
    generator.collective_trend_outliers(*config)
    
    # save train
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-train.txt"
    np.savetxt(SAVE_DIR+file_name, generator.train)
    
    # save test
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-test.txt"
    np.savetxt(SAVE_DIR+file_name, generator.test)
    
    # save labels
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-labels.txt"
    np.savetxt(SAVE_DIR+file_name, generator.label)

# %%
# Collective Seasonal
out_type = "collective_seasonal"
config_1 = [0.1, 1.1, 50] #ratio, factor, radius
config_2 = [0.1, 1.25, 50] #ratio, factor, radius
config_3 = [0.1, 1.5, 50] #ratio, factor, radius
config_4 = [0.1, 2, 50] #ratio, factor, radius
config_5 = [0.1, 3, 50] #ratio, factor, radius

for idx, config in enumerate([config_1, config_2, config_3, config_4, config_5]):
    generator = UnivariateDataGenerator(stream_length=5000)
    generator.collective_seasonal_outliers(*config)
    
    # save train
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-train.txt"
    np.savetxt(SAVE_DIR+file_name, generator.train)
    
    # save test
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-test.txt"
    np.savetxt(SAVE_DIR+file_name, generator.test)
    
    # save labels
    file_name = f"{out_type}/{idx}-{out_type}-factor{config[1]}-labels.txt"
    np.savetxt(SAVE_DIR+file_name, generator.label)

# %% [markdown]
# # Visualize Dataset

# %%
PATH0 = "./data/univar-synth/point_global/"
PATH1 = "./data/univar-synth/point_contextual/"
PATH2 = "./data/univar-synth/collective_global/"
PATH3 = "./data/univar-synth/collective_trend/"
PATH4 = "./data/univar-synth/collective_seasonal/"
PATHS = [PATH0, PATH1, PATH2, PATH3, PATH4]

# %%
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    
    for f in file_list:
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        fig, axes = plt.subplots(2)
        axes[0].set_title(f)
        axes[0].plot(test)
        axes[1].plot(labels)

# %% [markdown]
# # Scoring Helper

# %%
class ScoreCounter:
    def __init__(self):
        self.tp = 0
        self.fp = 0
        self.tn = 0
        self.fn = 0
        
    def process(self, preds, labels):
        preds = preds.copy()
        labels = labels.copy()
        ground_truth_ones = np.where(labels == 1)[0]
        pred_ones = np.where(preds == 1)[0]
        
        ranges = self._consecutive(ground_truth_ones)
        
        tp, fp, tn, fn = 0, 0, 0, 0
        
        for r in ranges:
            intersect = np.intersect1d(r, pred_ones, assume_unique=True)
            if intersect.size != 0:
                tp += r.size
                preds[intersect] = 0
                pred_ones = np.where(preds == 1)[0]
            else:
                fn += r.size
            
        fp += pred_ones.size
        tn += preds.size - tp - fp - fn
        
        self.tp += tp
        self.fp += fp
        self.tn += tn
        self.fn += fn
        
        
        return
        
        
    def _consecutive(self, data, stepsize=1):
        return np.split(data, np.where(np.diff(data) != stepsize)[0]+1)
    
    
    @property
    def tpr(self):
        return self.tp/(self.fn+self.tp)
    
    @property
    def fpr(self):
        return self.fp/(self.tn+self.fp)
    
    @property
    def tnr(self):
        return self.tn/(self.tn+self.fp)
        
    @property
    def fnr(self):
        return self.fn/(self.fn+self.tp)
        
    @property
    def precision(self):
        return self.tp/(self.tp+self.fp)
    
    @property
    def recall(self):
        return self.tp/(self.tp+self.fn)
    
    @property
    def f1(self):
        return (2*self.precision*self.recall)/(self.precision+self.recall)

# %% [markdown]
# # Run Experiments

# %% [markdown]
# ## Baselines

# %% [markdown]
# ### -- Setup

# %%
PATH0 = "./data/univar-synth/point_global/"
PATH1 = "./data/univar-synth/point_contextual/"
PATH2 = "./data/univar-synth/collective_global/"
PATH3 = "./data/univar-synth/collective_trend/"
PATH4 = "./data/univar-synth/collective_seasonal/"

# %%
PATHS = [PATH0, PATH1, PATH2, PATH3, PATH4]

# %%
SAVE_DIR = "./results/univar-synth/untuned/"

# %% [markdown]
# ### Quantile

# %%
# Quantile Model
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        window = 500
        test_extend = np.concatenate((train[-window:], test))
        model = QuantileModel(window)
        scores = model.get_scores(test_extend)[window:] 
        
        save = SAVE_DIR+"quantile/"+f
        os.makedirs(SAVE_DIR+"quantile/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", scores)
        
        scorer.process(scores, labels)
       
    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### MA

# %%
# Moving Average Model
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        window = 50
        test_extend = np.concatenate((train[-window:], test))
        model = MovingAverageModel(window)
        scores = model.get_scores(test_extend)[window:] 

        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.9)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        save = SAVE_DIR+"ma/"+f
        os.makedirs(SAVE_DIR+"ma/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)
        
        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### ARIMA

# %%
# ARIMA
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        test_extend = np.concatenate((train[-window:], test))
        model = ARIMAModel(1,1,1)
        model.fit(train)
        scores = model.get_scores(test_extend)[window:] 

        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.9)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        save = SAVE_DIR+"arima/"+f
        os.makedirs(SAVE_DIR+"arima/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)
        
        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### IForest

# %%
# IsolationForest
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        model = IsolationForestModel()
        model.fit(train)
        scores = model.get_scores(test)
            
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.9)
       
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"iforest/"+f
        os.makedirs(SAVE_DIR+"iforest/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


        scorer.process(preds, labels)
       
    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Regression

# %%
# RegressionModel
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 10
        
        test_extend = np.concatenate((train[-window:], test))
        model = RegressionModel(window)
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"regression/"+f
        os.makedirs(SAVE_DIR+"regression/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### NBEATS

# %%
# NBEATSModel
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 100
        
        test_extend = np.concatenate((train[-window:], test))
        model = NBEATSModel(window, use_gpu=True)
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nbeats/"+f
        os.makedirs(SAVE_DIR+"nbeats/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### NHiTS

# %%
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 100
        
        test_extend = np.concatenate((train[-window:], test))
        model = NHiTSModel(window, use_gpu=True)
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nhits/"+f
        os.makedirs(SAVE_DIR+"nhits/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### RNN(GRU)

# %%
import warnings
warnings.filterwarnings('ignore')


for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 100
        
        test_extend = np.concatenate((train[-window:], test))
        model = RNNModel(window, use_gpu=True, rnn_model="GRU")
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"rnn_gru/"+f
        os.makedirs(SAVE_DIR+"rnn_gru/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### TCN

# %%
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 100
        
        test_extend = np.concatenate((train[-window:], test))
        model = TCNModel(window, use_gpu=True)
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"tcn/"+f
        os.makedirs(SAVE_DIR+"tcn/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Transformer

# %%
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        window = 100
        
        test_extend = np.concatenate((train[-window:], test))
        model = TransformerModel(window, use_gpu=True)
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, 1e-1, 0.90)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"transformer/"+f
        os.makedirs(SAVE_DIR+"transformer/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ## F1 Tuned - 100% dataset

# %% [markdown]
# ### -- Setup

# %%
from one.models import *
from one.utils import *
from one.scorer.pot import *
from numpy.lib.stride_tricks import sliding_window_view

# %%
PATH0 = "./data/univar-synth/point_global/"
PATH1 = "./data/univar-synth/point_contextual/"
PATH2 = "./data/univar-synth/collective_global/"
PATH3 = "./data/univar-synth/collective_trend/"
PATH4 = "./data/univar-synth/collective_seasonal/"

# %%
PATHS = [PATH0, PATH1, PATH2, PATH3, PATH4]

# %%
SAVE_DIR = "./results/univar-synth/f1tuned-100pct/"

# %%
optuna.logging.set_verbosity(optuna.logging.FATAL)

# %% [markdown]
# ### Quantile

# %%
# Quantile Model
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        def objective(trial):
            s = ScoreCounter()
            window = trial.suggest_int("window", 100, 1000)
            threshold = trial.suggest_float("threshold", 0.95, 0.999)
            
            test_extend = np.concatenate((train[-window:], test))
            model = QuantileModel(window)
            scores = model.get_scores(test_extend)[window:] 
            

            s.process(preds, labels)
       
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            return s.f1
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        window = study.best_params["window"]
        threshold = study.best_params["threshold"]
        model = QuantileModel(window, threshold)
        
        test_extend = np.concatenate((train[-window:], test))
        
        scores = model.get_scores(test_extend)[window:] 
        
        # Save results
        save = SAVE_DIR+"quantile/"+f
        os.makedirs(SAVE_DIR+"quantile/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", scores)

        scorer.process(scores, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### MA

# %%
# MA Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        
        def objective(trial):
            s = ScoreCounter()
            window = trial.suggest_int("window", 10, 150)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], test))
            model = MovingAverageModel(window)
            scores = np.abs(model.get_scores(test_extend)[window:])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            return s.f1
            
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        window = study.best_params["window"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        model = MovingAverageModel(window)
        
        test_extend = np.concatenate((train[-window:], test))
        
        scores = np.abs(model.get_scores(test_extend)[window:] )
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"ma/"+f
        os.makedirs(SAVE_DIR+"ma/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### ARIMA

# %%
# ARIMA Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        def objective(trial):
            s = ScoreCounter()
            
            p = trial.suggest_int("p", 1, 20)
            d = trial.suggest_int("d", 0, 3)
            q = trial.suggest_int("q", 0, 20)
            q_risk = trial.suggest_float("q_risk", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
 
            test_extend = np.concatenate((train[-window:], test))
                
            model = ARIMAModel(p, d, q)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend))

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q_risk, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=20)
       
        p = study.best_params["p"]
        d = study.best_params["d"]
        q = study.best_params["q"]
        q_risk = study.best_params["q_risk"]
        contam = study.best_params["contam"]
        
        model = ARIMAModel(p, d, q)
        model.fit(train)
        test_extend = np.concatenate((train[-window:], test))
        scores = np.abs(model.get_scores(test_extend))
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q_risk, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"arima/"+f
        os.makedirs(SAVE_DIR+"arima/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### IForest

# %%
# IForest Model 
import warnings
warnings.filterwarnings('error')


for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        
        def objective(trial):
            s = ScoreCounter()
            q = trial.suggest_float("q", 1e-5, 1e-1)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
                
            model = IsolationForestModel()
            model.fit(train)
            scores = np.abs(model.get_scores(test))

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
            
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        model = IsolationForestModel()
        model.fit(train)
        scores = np.abs(model.get_scores(test))
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"iforest/"+f
        os.makedirs(SAVE_DIR+"iforest/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Regression

# %%
# Regression Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            lags = trial.suggest_int("lags", 1, 5)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
 
            test_extend = np.concatenate((train[-window:], test))
                
            model = RegressionModel(window, n_steps, lags)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=50)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        lags = study.best_params["lags"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
        model = RegressionModel(window,n_steps, lags)
        model.fit(train)
        test_extend = np.concatenate((train[-window:], test))
        scores = np.abs(model.get_scores(test_extend)[0])
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"regression/"+f
        os.makedirs(SAVE_DIR+"regression/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### NBEATS

# %%
# %%capture
# NBEATSModel
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "num_blocks": trial.suggest_int("num_blocks", 1, 2),
#              "num_stacks": trial.suggest_int("num_stacks", 2, 32),
#              "num_layers": trial.suggest_int("num_layers", 1, 16),
#              "layer_widths": trial.suggest_int("layer_widths", 128, 512),
#              "expansion_coefficient_dim": trial.suggest_int(
#                  "expansion_coefficient_dim", 1, 10
#              ),
#             } 
 
            test_extend = np.concatenate((train[-window:], test))
                
            model = NBEATSModel(window, n_steps, use_gpu=True)            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "num_blocks": study.best_params["num_blocks"],
#          "num_stacks": study.best_params["num_stacks"],
#          "num_layers": study.best_params["num_layers"],
#          "layer_widths": study.best_params["layer_widths"],
#          "expansion_coefficient_dim": study.best_params["expansion_coefficient_dim"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = NBEATSModel(window, n_steps, use_gpu=True)
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nbeats/"+f
        os.makedirs(SAVE_DIR+"nbeats/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"nbeats/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### NHiTs

# %%
# %%capture #supress output
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], test))
                
            model = NHiTSModel(window, n_steps, use_gpu=True)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        

        test_extend = np.concatenate((train[-window:], test))
        model = NHiTSModel(window, n_steps, use_gpu=True)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nhits/"+f
        os.makedirs(SAVE_DIR+"nhits/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"nhits/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %%
# for path in PATHS:
#     scorer = ScoreCounter()
#     file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
#     for f in file_list:
#         labels = np.loadtxt(path+f+"-labels.txt")
#         preds = np.loadtxt(SAVE_DIR+"nhits/"+f+"-preds.txt")
#         scorer.process(preds, labels)
        
#     print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### RNN(GRU)

# %%
# %%capture
#supress output

for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "hidden_dim": trial.suggest_int("hidden_dim", 10, 256),
#              "n_rnn_layers": trial.suggest_int("n_rnn_layers", 1, 64),
#              "dropout": trial.suggest_float("dropout", 0.0, 0.3),
#              } 
 
            test_extend = np.concatenate((train[-window:], test))
                
            model = RNNModel(window, n_steps, rnn_model="GRU")
#             model.params = params
#             model._init_model(**model.params)
            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "hidden_dim": study.best_params["hidden_dim"],
#          "n_rnn_layers": study.best_params["n_rnn_layers"],
#          "dropout": study.best_params["dropout"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = RNNModel(window, n_steps, use_gpu=True, rnn_model="GRU")
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"rnn_gru/"+f
        os.makedirs(SAVE_DIR+"rnn_gru/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"rnn_gru/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}\n")

# %% [markdown]
# ### TCN

# %%
#supress output
# %%capture
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "kernel_size": trial.suggest_int(
#                  "kernel_size", 2, min(32, window - 1)
#              ),
#              "num_filters": trial.suggest_int("num_filters", 2, 8),
#              "weight_norm": trial.suggest_categorical("weight_norm", [True, False]),
#              "dilation_base": trial.suggest_int("dilation_base", 1, 4),
#              "dropout": trial.suggest_float("dropout", 0.0, 0.3),
#              }
                
            test_extend = np.concatenate((train[-window:], test))
            
            model = TCNModel(window, n_steps, use_gpu=True)
            #model.params = params
            #model._init_model(**model.params)
            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "kernel_size": study.best_params["kernel_size"],
#          "num_filters": study.best_params["num_filters"],
#          "dilation_base": study.best_params["dilation_base"],
#          "dropout": study.best_params["dropout"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = TCNModel(window, n_steps, use_gpu=True)
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"tcn/"+f
        os.makedirs(SAVE_DIR+"tcn/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"tcn/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Transformer

# %%
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], test))
                
            model = TransformerModel(window, n_steps, use_gpu=True)
            # %%capture #supress output
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        

        test_extend = np.concatenate((train[-window:], test))
        model = TransformerModel(window, n_steps, use_gpu=True)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"transformer/"+f
        os.makedirs(SAVE_DIR+"transformer/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"transformer/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %%
for path in PATHS:
    scorer = ScoreCounter()
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    for f in file_list:
        labels = np.loadtxt(path+f+"-labels.txt")
        preds = np.loadtxt(SAVE_DIR+"transformer/"+f+"-preds.txt")
        scorer.process(preds, labels)
        
    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ## F1 Tuned - 50% dataset

# %% [markdown]
# ### -- Setup

# %%
from one.models import *
from one.utils import *
from one.scorer.pot import *
from numpy.lib.stride_tricks import sliding_window_view

# %%
PATH0 = "./data/univar-synth/point_global/"
PATH1 = "./data/univar-synth/point_contextual/"
PATH2 = "./data/univar-synth/collective_global/"
PATH3 = "./data/univar-synth/collective_trend/"
PATH4 = "./data/univar-synth/collective_seasonal/"

# %%
PATHS = [PATH0, PATH1, PATH2, PATH3, PATH4]

# %%
SAVE_DIR = "./results/univar-synth/f1tuned-50pct/"

# %%
optuna.logging.set_verbosity(optuna.logging.FATAL)

# %% [markdown]
# ### Quantile

# %%
# Quantile Model
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")

        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]
        
        def objective(trial):
            s = ScoreCounter()
            window = trial.suggest_int("window", 100, 1000)
            threshold = trial.suggest_float("threshold", 0.95, 0.999)
            
            test_extend = np.concatenate((train[-window:], tune_data))
            model = QuantileModel(window)
            scores = model.get_scores(test_extend)[window:] 
            

            s.process(preds, tune_labels)
       
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            return s.f1
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        window = study.best_params["window"]
        threshold = study.best_params["threshold"]
        model = QuantileModel(window, threshold)
        
        test_extend = np.concatenate((train[-window:], test))
        
        scores = model.get_scores(test_extend)[window:] 
        
        # Save results
        save = SAVE_DIR+"quantile/"+f
        os.makedirs(SAVE_DIR+"quantile/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", scores)

        scorer.process(scores, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### MA

# %%
# MA Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]
        
        def objective(trial):
            s = ScoreCounter()
            window = trial.suggest_int("window", 10, 150)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], tune_data))
            model = MovingAverageModel(window)
            scores = np.abs(model.get_scores(test_extend)[window:])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            return s.f1
            
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        window = study.best_params["window"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        model = MovingAverageModel(window)
        
        test_extend = np.concatenate((train[-window:], test))
        
        scores = np.abs(model.get_scores(test_extend)[window:] )
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"ma/"+f
        os.makedirs(SAVE_DIR+"ma/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### ARIMA

# %%
# ARIMA Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]


        def objective(trial):
            s = ScoreCounter()
            
            p = trial.suggest_int("p", 1, 20)
            d = trial.suggest_int("d", 0, 3)
            q = trial.suggest_int("q", 0, 20)
            q_risk = trial.suggest_float("q_risk", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
 
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = ARIMAModel(p, d, q)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend))

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q_risk, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=20)
       
        p = study.best_params["p"]
        d = study.best_params["d"]
        q = study.best_params["q"]
        q_risk = study.best_params["q_risk"]
        contam = study.best_params["contam"]
        
        model = ARIMAModel(p, d, q)
        model.fit(train)
        test_extend = np.concatenate((train[-window:], test))
        scores = np.abs(model.get_scores(test_extend))
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q_risk, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"arima/"+f
        os.makedirs(SAVE_DIR+"arima/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### IForest

# %%
# IForest Model 
import warnings
warnings.filterwarnings('error')


for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")

        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        def objective(trial):
            s = ScoreCounter()
            q = trial.suggest_float("q", 1e-5, 1e-1)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
                
            model = IsolationForestModel()
            model.fit(train)
            scores = np.abs(model.get_scores(tune_data))

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
            
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=150)
       
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        model = IsolationForestModel()
        model.fit(train)
        scores = np.abs(model.get_scores(test))
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"iforest/"+f
        os.makedirs(SAVE_DIR+"iforest/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Regression

# %%
# Regression Model 
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            lags = trial.suggest_int("lags", 1, 5)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
 
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = RegressionModel(window, n_steps, lags)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
       
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=50)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        lags = study.best_params["lags"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
        model = RegressionModel(window,n_steps, lags)
        model.fit(train)
        test_extend = np.concatenate((train[-window:], test))
        scores = np.abs(model.get_scores(test_extend)[0])
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1

        scorer.process(preds, labels)
        
        # Save results
        save = SAVE_DIR+"regression/"+f
        os.makedirs(SAVE_DIR+"regression/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores)
        np.savetxt(save+"-preds.txt", preds)


    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### NBEATS

# %%
# %%capture
# NBEATSModel
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]
        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "num_blocks": trial.suggest_int("num_blocks", 1, 2),
#              "num_stacks": trial.suggest_int("num_stacks", 2, 32),
#              "num_layers": trial.suggest_int("num_layers", 1, 16),
#              "layer_widths": trial.suggest_int("layer_widths", 128, 512),
#              "expansion_coefficient_dim": trial.suggest_int(
#                  "expansion_coefficient_dim", 1, 10
#              ),
#             } 
 
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = NBEATSModel(window, n_steps, use_gpu=True)            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "num_blocks": study.best_params["num_blocks"],
#          "num_stacks": study.best_params["num_stacks"],
#          "num_layers": study.best_params["num_layers"],
#          "layer_widths": study.best_params["layer_widths"],
#          "expansion_coefficient_dim": study.best_params["expansion_coefficient_dim"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = NBEATSModel(window, n_steps, use_gpu=True)
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nbeats/"+f
        os.makedirs(SAVE_DIR+"nbeats/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"nbeats/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
# Out:
# [2022-07-04 12:09:44,146] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 654 samples.
# [2022-07-04 12:09:44,146] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 654 samples.
# 2022-07-04 12:09:44 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 654 samples.
# [2022-07-04 12:09:44,302] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:09:44,302] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:09:44 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:09:44 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:09:44 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:09:44 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:09:44 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:09:48 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:09:48 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.2 M
# -----------------------------------------
# 7.2 M     Trainable params
# 2.2 K     Non-trainable params
# 7.2 M     Total params
# 28.615    Total estimated model params size (MB)
# 2022-07-04 12:10:30 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:10:36,657] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 768 samples.
# [2022-07-04 12:10:36,657] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 768 samples.
# 2022-07-04 12:10:36 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 768 samples.
# [2022-07-04 12:10:36,778] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:10:36,778] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:10:36 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:10:36 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:10:36 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:10:36 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:10:36 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:10:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:10:36 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.2 M
# -----------------------------------------
# 6.2 M     Trainable params
# 1.5 K     Non-trainable params
# 6.2 M     Total params
# 24.908    Total estimated model params size (MB)
# 2022-07-04 12:11:28 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:11:30,042] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 671 samples.
# [2022-07-04 12:11:30,042] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 671 samples.
# 2022-07-04 12:11:30 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 671 samples.
# [2022-07-04 12:11:30,165] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:11:30,165] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:11:30 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:11:30 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:11:30 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:11:30 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:11:30 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:11:30 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:11:30 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.0 M
# -----------------------------------------
# 7.0 M     Trainable params
# 2.1 K     Non-trainable params
# 7.0 M     Total params
# 28.081    Total estimated model params size (MB)
# 2022-07-04 12:12:18 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:12:24,691] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 774 samples.
# [2022-07-04 12:12:24,691] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 774 samples.
# 2022-07-04 12:12:24 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 774 samples.
# [2022-07-04 12:12:24,792] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:12:24,792] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:12:24 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:12:24 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:12:24 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:12:24 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:12:24 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:12:24 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:12:24 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.2 M
# -----------------------------------------
# 6.2 M     Trainable params
# 1.4 K     Non-trainable params
# 6.2 M     Total params
# 24.689    Total estimated model params size (MB)
# 2022-07-04 12:13:21 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:13:22,745] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 660 samples.
# [2022-07-04 12:13:22,745] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 660 samples.
# 2022-07-04 12:13:22 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 660 samples.
# [2022-07-04 12:13:22,855] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:13:22,855] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:13:22 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:13:22 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:13:22 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:13:22 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:13:22 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:13:22 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:13:23 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.1 M
# -----------------------------------------
# 7.1 M     Trainable params
# 2.1 K     Non-trainable params
# 7.1 M     Total params
# 28.396    Total estimated model params size (MB)
# 2022-07-04 12:14:11 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:14:14,874] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 732 samples.
# [2022-07-04 12:14:14,874] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 732 samples.
# 2022-07-04 12:14:14 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 732 samples.
# [2022-07-04 12:14:14,979] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:14:14,979] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:14:14 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:14:14 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:14:14 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:14:14 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:14:14 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:14:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:14:15 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.5 M
# -----------------------------------------
# 6.5 M     Trainable params
# 1.7 K     Non-trainable params
# 6.5 M     Total params
# 26.163    Total estimated model params size (MB)
# 2022-07-04 12:15:01 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:15:07,727] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 749 samples.
# [2022-07-04 12:15:07,727] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 749 samples.
# 2022-07-04 12:15:07 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 749 samples.
# [2022-07-04 12:15:07,852] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:15:07,852] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:15:07 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:15:07 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:15:07 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:15:07 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:15:07 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:15:07 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:15:08 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.4 M
# -----------------------------------------
# 6.4 M     Trainable params
# 1.6 K     Non-trainable params
# 6.4 M     Total params
# 25.628    Total estimated model params size (MB)
# 2022-07-04 12:15:56 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:16:02,127] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 745 samples.
# [2022-07-04 12:16:02,127] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 745 samples.
# 2022-07-04 12:16:02 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 745 samples.
# [2022-07-04 12:16:02,233] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:16:02,233] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:16:02 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:16:02 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:16:02 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:16:02 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:16:02 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:16:02 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:16:02 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.4 M
# -----------------------------------------
# 6.4 M     Trainable params
# 1.6 K     Non-trainable params
# 6.4 M     Total params
# 25.723    Total estimated model params size (MB)
# 2022-07-04 12:17:09 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:17:12,606] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 751 samples.
# [2022-07-04 12:17:12,606] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 751 samples.
# 2022-07-04 12:17:12 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 751 samples.
# [2022-07-04 12:17:12,724] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:17:12,724] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:17:12 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:17:12 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:17:12 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:17:12 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:17:12 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:17:12 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:17:12 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.4 M
# -----------------------------------------
# 6.4 M     Trainable params
# 1.6 K     Non-trainable params
# 6.4 M     Total params
# 25.566    Total estimated model params size (MB)
# 2022-07-04 12:18:07 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:18:13,602] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 724 samples.
# [2022-07-04 12:18:13,602] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 724 samples.
# 2022-07-04 12:18:13 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 724 samples.
# [2022-07-04 12:18:13,729] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:18:13,729] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:18:13 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:18:13 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:18:13 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:18:13 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:18:13 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:18:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:18:13 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.6 M
# -----------------------------------------
# 6.6 M     Trainable params
# 1.7 K     Non-trainable params
# 6.6 M     Total params
# 26.353    Total estimated model params size (MB)
# 2022-07-04 12:19:05 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:19:07,734] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 685 samples.
# [2022-07-04 12:19:07,734] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 685 samples.
# 2022-07-04 12:19:07 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 685 samples.
# [2022-07-04 12:19:07,848] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:19:07,848] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:19:07 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:19:07 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:19:07 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:19:07 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:19:07 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:19:07 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:19:07 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.8 M
# -----------------------------------------
# 6.8 M     Trainable params
# 1.9 K     Non-trainable params
# 6.8 M     Total params
# 27.395    Total estimated model params size (MB)
# 2022-07-04 12:19:56 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:19:57,984] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 677 samples.
# [2022-07-04 12:19:57,984] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 677 samples.
# 2022-07-04 12:19:57 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 677 samples.
# [2022-07-04 12:19:58,099] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:19:58,099] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:19:58 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:19:58 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:19:58 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:19:58 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:19:58 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:19:58 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:19:58 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.9 M
# -----------------------------------------
# 6.9 M     Trainable params
# 2.0 K     Non-trainable params
# 6.9 M     Total params
# 27.708    Total estimated model params size (MB)
# 2022-07-04 12:20:47 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:20:49,086] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 685 samples.
# [2022-07-04 12:20:49,086] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 685 samples.
# 2022-07-04 12:20:49 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 685 samples.
# [2022-07-04 12:20:49,191] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:20:49,191] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:20:49 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:20:49 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:20:49 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:20:49 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:20:49 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:20:49 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:20:49 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.9 M
# -----------------------------------------
# 6.9 M     Trainable params
# 2.0 K     Non-trainable params
# 6.9 M     Total params
# 27.579    Total estimated model params size (MB)
# 2022-07-04 12:21:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:21:36,285] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 641 samples.
# [2022-07-04 12:21:36,285] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 641 samples.
# 2022-07-04 12:21:36 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 641 samples.
# [2022-07-04 12:21:36,667] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:21:36,667] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:21:36 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:21:36 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:21:36 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:21:36 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:21:36 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:21:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:21:36 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.2 M
# -----------------------------------------
# 7.2 M     Trainable params
# 2.2 K     Non-trainable params
# 7.2 M     Total params
# 28.747    Total estimated model params size (MB)
# 2022-07-04 12:22:35 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:22:36,341] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 691 samples.
# [2022-07-04 12:22:36,341] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 691 samples.
# 2022-07-04 12:22:36 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 691 samples.
# [2022-07-04 12:22:36,463] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:22:36,463] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:22:36 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:22:36 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:22:36 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:22:36 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:22:36 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:22:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:22:36 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.8 M
# -----------------------------------------
# 6.8 M     Trainable params
# 1.9 K     Non-trainable params
# 6.8 M     Total params
# 27.329    Total estimated model params size (MB)
# 2022-07-04 12:23:37 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:23:39,389] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 674 samples.
# [2022-07-04 12:23:39,389] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 674 samples.
# 2022-07-04 12:23:39 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 674 samples.
# [2022-07-04 12:23:39,498] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:23:39,498] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:23:39 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:23:39 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:23:39 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:23:39 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:23:39 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:23:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:23:39 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.0 M
# -----------------------------------------
# 7.0 M     Trainable params
# 2.0 K     Non-trainable params
# 7.0 M     Total params
# 27.956    Total estimated model params size (MB)
# 2022-07-04 12:24:23 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:24:27,075] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 705 samples.
# [2022-07-04 12:24:27,075] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 705 samples.
# 2022-07-04 12:24:27 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 705 samples.
# [2022-07-04 12:24:27,224] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:24:27,224] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:24:27 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:24:27 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:24:27 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:24:27 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:24:27 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:24:27 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:24:27 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.950    Total estimated model params size (MB)
# 2022-07-04 12:25:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:25:15,737] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 646 samples.
# [2022-07-04 12:25:15,737] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 646 samples.
# 2022-07-04 12:25:15 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 646 samples.
# [2022-07-04 12:25:15,852] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:25:15,852] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:25:15 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:25:15 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:25:15 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:25:15 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:25:15 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:25:15 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:25:16 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.2 M
# -----------------------------------------
# 7.2 M     Trainable params
# 2.2 K     Non-trainable params
# 7.2 M     Total params
# 28.713    Total estimated model params size (MB)
# 2022-07-04 12:26:09 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:26:10,577] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 668 samples.
# [2022-07-04 12:26:10,577] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 668 samples.
# 2022-07-04 12:26:10 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 668 samples.
# [2022-07-04 12:26:10,680] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:26:10,680] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:26:10 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:26:10 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:26:10 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:26:10 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:26:10 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:26:10 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:26:10 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.0 M
# -----------------------------------------
# 7.0 M     Trainable params
# 2.0 K     Non-trainable params
# 7.0 M     Total params
# 27.991    Total estimated model params size (MB)
# 2022-07-04 12:26:58 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:26:59,615] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 704 samples.
# [2022-07-04 12:26:59,615] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 704 samples.
# 2022-07-04 12:26:59 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 704 samples.
# [2022-07-04 12:26:59,741] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:26:59,741] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:26:59 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:26:59 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:26:59 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:26:59 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:26:59 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:26:59 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:26:59 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.951    Total estimated model params size (MB)
# 2022-07-04 12:28:02 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:28:04,374] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 708 samples.
# [2022-07-04 12:28:04,374] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 708 samples.
# 2022-07-04 12:28:04 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 708 samples.
# [2022-07-04 12:28:04,490] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:28:04,490] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:28:04 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:28:04 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:28:04 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:28:04 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:28:04 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:28:04 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:28:04 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.825    Total estimated model params size (MB)
# 2022-07-04 12:28:50 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:28:52,433] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 680 samples.
# [2022-07-04 12:28:52,433] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 680 samples.
# 2022-07-04 12:28:52 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 680 samples.
# [2022-07-04 12:28:52,551] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:28:52,551] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:28:52 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:28:52 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:28:52 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:28:52 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:28:52 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:28:52 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:28:52 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.9 M
# -----------------------------------------
# 6.9 M     Trainable params
# 2.0 K     Non-trainable params
# 6.9 M     Total params
# 27.613    Total estimated model params size (MB)
# 2022-07-04 12:29:41 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:29:43,308] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 704 samples.
# [2022-07-04 12:29:43,308] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 704 samples.
# 2022-07-04 12:29:43 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 704 samples.
# [2022-07-04 12:29:43,425] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:29:43,425] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:29:43 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:29:43 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:29:43 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:29:43 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:29:43 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:29:43 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:29:43 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.951    Total estimated model params size (MB)
# 2022-07-04 12:30:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:30:36,627] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 656 samples.
# [2022-07-04 12:30:36,627] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 656 samples.
# 2022-07-04 12:30:36 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 656 samples.
# [2022-07-04 12:30:36,739] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:30:36,739] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:30:36 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:30:36 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:30:36 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:30:36 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:30:36 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:30:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:30:36 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.1 M
# -----------------------------------------
# 7.1 M     Trainable params
# 2.1 K     Non-trainable params
# 7.1 M     Total params
# 28.337    Total estimated model params size (MB)
# 2022-07-04 12:31:37 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:31:38,839] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 659 samples.
# [2022-07-04 12:31:38,839] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 659 samples.
# 2022-07-04 12:31:38 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 659 samples.
# [2022-07-04 12:31:38,941] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:31:38,941] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:31:38 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:31:38 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:31:38 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:31:38 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:31:38 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:31:39 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:31:39 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.1 M
# -----------------------------------------
# 7.1 M     Trainable params
# 2.1 K     Non-trainable params
# 7.1 M     Total params
# 28.243    Total estimated model params size (MB)
# 2022-07-04 12:32:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:32:34,392] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 697 samples.
# [2022-07-04 12:32:34,392] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 697 samples.
# 2022-07-04 12:32:34 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 697 samples.
# [2022-07-04 12:32:34,509] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:32:34,509] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:32:34 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:32:34 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:32:34 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:32:34 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:32:34 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:32:34 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:32:34 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.8 M
# -----------------------------------------
# 6.8 M     Trainable params
# 1.9 K     Non-trainable params
# 6.8 M     Total params
# 27.140    Total estimated model params size (MB)
# 2022-07-04 12:33:18 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:33:20,022] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 687 samples.
# [2022-07-04 12:33:20,022] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 687 samples.
# 2022-07-04 12:33:20 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 687 samples.
# [2022-07-04 12:33:20,127] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-04 12:33:20,127] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:33:20 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-04 12:33:20 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-04 12:33:20 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-04 12:33:20 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-04 12:33:20 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-04 12:33:20 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-04 12:33:20 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.8 M
# -----------------------------------------
# 6.8 M     Trainable params
# 1.9 K     Non-trainable params
# 6.8 M     Total params
# 27.301    Total estimated model params size (MB)
# 2022-07-04 12:34:09 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-04 12:34:10,465] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 678 samples.
# [2022-07-04 12:34:10,465] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 678 samples.
# ...
# 2022-07-05 05:52:16 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:52:18,790] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 710 samples.
# [2022-07-05 05:52:18,790] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 710 samples.
# 2022-07-05 05:52:18 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 710 samples.
# [2022-07-05 05:52:18,912] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:52:18,912] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:52:18 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:52:18 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:52:18 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:52:18 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:52:18 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:52:19 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:52:19 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.609    Total estimated model params size (MB)
# 2022-07-05 05:53:29 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:53:31,184] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 728 samples.
# [2022-07-05 05:53:31,184] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 728 samples.
# 2022-07-05 05:53:31 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 728 samples.
# [2022-07-05 05:53:31,315] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:53:31,315] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:53:31 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:53:31 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:53:31 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:53:31 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:53:31 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:53:31 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:53:31 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.6 M
# -----------------------------------------
# 6.6 M     Trainable params
# 1.7 K     Non-trainable params
# 6.6 M     Total params
# 26.258    Total estimated model params size (MB)
# 2022-07-05 05:54:43 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:54:47,858] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 708 samples.
# [2022-07-05 05:54:47,858] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 708 samples.
# 2022-07-05 05:54:47 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 708 samples.
# [2022-07-05 05:54:48,017] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:54:48,017] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:54:48 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:54:48 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:54:48 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:54:48 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:54:48 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:54:48 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:54:48 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.825    Total estimated model params size (MB)
# 2022-07-05 05:56:10 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:56:13,412] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 666 samples.
# [2022-07-05 05:56:13,412] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 666 samples.
# 2022-07-05 05:56:13 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 666 samples.
# [2022-07-05 05:56:13,553] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:56:13,553] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:56:13 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:56:13 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:56:13 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:56:13 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:56:13 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:56:13 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:56:13 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 7.0 M
# -----------------------------------------
# 7.0 M     Trainable params
# 2.1 K     Non-trainable params
# 7.0 M     Total params
# 28.146    Total estimated model params size (MB)
# 2022-07-05 05:57:33 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:57:35,642] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 729 samples.
# [2022-07-05 05:57:35,642] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 729 samples.
# 2022-07-05 05:57:35 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 729 samples.
# [2022-07-05 05:57:35,814] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:57:35,814] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:57:35 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:57:35 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:57:35 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:57:35 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:57:35 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:57:35 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:57:35 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.5 M
# -----------------------------------------
# 6.5 M     Trainable params
# 1.7 K     Non-trainable params
# 6.5 M     Total params
# 25.981    Total estimated model params size (MB)
# 2022-07-05 05:58:49 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 05:58:51,134] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 706 samples.
# [2022-07-05 05:58:51,134] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 706 samples.
# 2022-07-05 05:58:51 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 706 samples.
# [2022-07-05 05:58:51,320] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 05:58:51,320] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:58:51 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 05:58:51 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 05:58:51 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 05:58:51 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 05:58:51 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 05:58:51 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 05:58:51 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.735    Total estimated model params size (MB)
# 2022-07-05 06:00:14 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 06:00:15,708] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 726 samples.
# [2022-07-05 06:00:15,708] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 726 samples.
# 2022-07-05 06:00:15 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 726 samples.
# [2022-07-05 06:00:15,906] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 06:00:15,906] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:00:15 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:00:15 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 06:00:15 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 06:00:15 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 06:00:15 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 06:00:16 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 06:00:16 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.6 M
# -----------------------------------------
# 6.6 M     Trainable params
# 1.7 K     Non-trainable params
# 6.6 M     Total params
# 26.321    Total estimated model params size (MB)
# 2022-07-05 06:01:31 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 06:01:35,695] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 734 samples.
# [2022-07-05 06:01:35,695] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 734 samples.
# 2022-07-05 06:01:35 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 734 samples.
# [2022-07-05 06:01:35,890] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 06:01:35,890] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:01:35 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:01:35 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 06:01:35 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 06:01:35 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 06:01:35 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 06:01:36 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 06:01:36 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.5 M
# -----------------------------------------
# 6.5 M     Trainable params
# 1.7 K     Non-trainable params
# 6.5 M     Total params
# 25.946    Total estimated model params size (MB)
# 2022-07-05 06:02:50 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2022-07-05 06:02:52,386] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 712 samples.
# [2022-07-05 06:02:52,386] INFO | darts.models.forecasting.torch_forecasting_model | Train dataset contains 712 samples.
# 2022-07-05 06:02:52 darts.models.forecasting.torch_forecasting_model INFO: Train dataset contains 712 samples.
# [2022-07-05 06:02:52,552] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# [2022-07-05 06:02:52,552] INFO | darts.models.forecasting.torch_forecasting_model | Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:02:52 darts.models.forecasting.torch_forecasting_model INFO: Time series values are 32-bits; casting model to float32.
# 2022-07-05 06:02:52 pytorch_lightning.utilities.rank_zero INFO: GPU available: True, used: True
# 2022-07-05 06:02:52 pytorch_lightning.utilities.rank_zero INFO: TPU available: False, using: 0 TPU cores
# 2022-07-05 06:02:52 pytorch_lightning.utilities.rank_zero INFO: IPU available: False, using: 0 IPUs
# 2022-07-05 06:02:52 pytorch_lightning.utilities.rank_zero INFO: HPU available: False, using: 0 HPUs
# 2022-07-05 06:02:52 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-07-05 06:02:52 pytorch_lightning.callbacks.model_summary INFO:
#   | Name      | Type       | Params
# -----------------------------------------
# 0 | criterion | MSELoss    | 0
# 1 | stacks    | ModuleList | 6.7 M
# -----------------------------------------
# 6.7 M     Trainable params
# 1.8 K     Non-trainable params
# 6.7 M     Total params
# 26.792    Total estimated model params size (MB)
# 2022-07-05 06:04:21 pytorch_lightning.accelerators.gpu INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %% [markdown]
# ### NHiTs

# %%
# %%capture
#supress output
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = NHiTSModel(window, n_steps, use_gpu=True)
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        

        test_extend = np.concatenate((train[-window:], test))
        model = NHiTSModel(window, n_steps, use_gpu=True)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"nhits/"+f
        os.makedirs(SAVE_DIR+"nhits/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"nhits/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %%
# for path in PATHS:
#     scorer = ScoreCounter()
#     file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
#     for f in file_list:
#         labels = np.loadtxt(path+f+"-labels.txt")
#         preds = np.loadtxt(SAVE_DIR+"nhits/"+f+"-preds.txt")
#         scorer.process(preds, labels)
        
#     print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### RNN(GRU)

# %%
# %%capture
#supress output

for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "hidden_dim": trial.suggest_int("hidden_dim", 10, 256),
#              "n_rnn_layers": trial.suggest_int("n_rnn_layers", 1, 64),
#              "dropout": trial.suggest_float("dropout", 0.0, 0.3),
#              } 
 
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = RNNModel(window, n_steps, rnn_model="GRU")
#             model.params = params
#             model._init_model(**model.params)
            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "hidden_dim": study.best_params["hidden_dim"],
#          "n_rnn_layers": study.best_params["n_rnn_layers"],
#          "dropout": study.best_params["dropout"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = RNNModel(window, n_steps, use_gpu=True, rnn_model="GRU")
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"rnn_gru/"+f
        os.makedirs(SAVE_DIR+"rnn_gru/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"rnn_gru/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}\n")

# %% [markdown]
# ### TCN

# %%
# %%capture

for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 9, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
#             params = {
#              "kernel_size": trial.suggest_int(
#                  "kernel_size", 2, min(32, window - 1)
#              ),
#              "num_filters": trial.suggest_int("num_filters", 2, 8),
#              "weight_norm": trial.suggest_categorical("weight_norm", [True, False]),
#              "dilation_base": trial.suggest_int("dilation_base", 1, 4),
#              "dropout": trial.suggest_float("dropout", 0.0, 0.3),
#              }
                
            test_extend = np.concatenate((train[-window:], tune_data))
            
            model = TCNModel(window, n_steps, use_gpu=True)
            #model.params = params
            #model._init_model(**model.params)
            
            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        
#         params = {
#          "kernel_size": study.best_params["kernel_size"],
#          "num_filters": study.best_params["num_filters"],
#          "dilation_base": study.best_params["dilation_base"],
#          "dropout": study.best_params["dropout"],
#         } 

        test_extend = np.concatenate((train[-window:], test))
        model = TCNModel(window, n_steps, use_gpu=True)
#         model.params = params
#         model._init_model(**model.params)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"tcn/"+f
        os.makedirs(SAVE_DIR+"tcn/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"tcn/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %% [markdown]
# ### Transformer

# %%
# %%capture
for path in PATHS:
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    scorer = ScoreCounter()
    for f in file_list:
        train = np.loadtxt(path+f+"-train.txt")
        test = np.loadtxt(path+f+"-test.txt")
        labels = np.loadtxt(path+f+"-labels.txt")
        
        n_tune = labels.size // 2
        tune_data, tune_labels = test[:n_tune], labels[:n_tune]

        
        def objective(trial):
            s = ScoreCounter()
            
            window = trial.suggest_int("window", 10, 150)
            n_steps = trial.suggest_int("n_steps", 1, 10, log=True)
            q = trial.suggest_float("q", 1e-5, 1e-1, log=True)
            contam = trial.suggest_float("contam", 0.90, 0.999)
            
            test_extend = np.concatenate((train[-window:], tune_data))
                
            model = TransformerModel(window, n_steps, use_gpu=True)

            model.fit(train)
            scores = np.abs(model.get_scores(test_extend)[0])

            # Get threshold (Not needed for Quantile)
            thres = pot(scores, q, contam)
            preds = scores.copy()
            preds[preds <= thres] = 0
            preds[preds > thres] = 1
 
            s.process(preds, tune_labels)
        
            if s.tp == 0 and s.fp == 0: return -1
            if s.tp == 0 and s.fn == 0: return -1

            if s.precision == 0 and s.recall == 0: return -1
            if np.isnan(s.f1): return -1
            return s.f1
 
        
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=35)
       
        window = study.best_params["window"]
        n_steps = study.best_params["n_steps"]
        q = study.best_params["q"]
        contam = study.best_params["contam"]
        

        test_extend = np.concatenate((train[-window:], test))
        model = TransformerModel(window, n_steps, use_gpu=True)
 
        model.fit(train)
        scores = model.get_scores(test_extend)[0]
        
        
        # Get threshold (Not needed for Quantile)
        thres = pot(scores, q, contam)
        
        # Get predictions from threshold
        preds = scores.copy()
        preds[preds <= thres] = 0
        preds[preds > thres] = 1
        
        # Save results
        save = SAVE_DIR+"transformer/"+f
        os.makedirs(SAVE_DIR+"transformer/", exist_ok=True)
        np.savetxt(save+"-scores.txt", scores, header=study.best_params.__str__())
        np.savetxt(save+"-preds.txt", preds, header=study.best_params.__str__())

        scorer.process(preds, labels)

    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
    with open(SAVE_DIR+"transformer/summary.txt", 'a+') as summary:
        summary.write(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")

# %%
for path in PATHS:
    scorer = ScoreCounter()
    file_list = ["-".join(f.split("-")[:-1]) for f in get_files_from_path(path) if "train" in f]
    for f in file_list:
        labels = np.loadtxt(path+f+"-labels.txt")
        preds = np.loadtxt(SAVE_DIR+"transformer/"+f+"-preds.txt")
        scorer.process(preds, labels)
        
    print(f"{scorer.tp}, {scorer.fp}, {scorer.tn}, {scorer.fn}, {scorer.tpr}, {scorer.fpr}, {scorer.tnr}, {scorer.fnr}, {scorer.precision}, {scorer.recall}, {scorer.f1}")
